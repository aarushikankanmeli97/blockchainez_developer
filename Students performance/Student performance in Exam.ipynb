# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = 20,8

# %%
marks_data = pd.read_csv("StudentsPerformance.csv")

# %%
marks_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
marks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
pass_mark = 35

# %%
marks_data.shape
# Out:
# (1000, 8)

# %%
marks_data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df= marks_data.groupby(by='math score').count()
df
# Out:
#             gender  race/ethnicity  parental level of education  lunch  \
# math score
# 0                1               1                            1      1
# 8                1               1                            1      1
# 18               1               1                            1      1
# 19               1               1                            1      1
# 22               1               1                            1      1
# 23               1               1                            1      1
# 24               1               1                            1      1
# 26               1               1                            1      1
# 27               2               2                            2      2
# 28               1               1                            1      1
# 29               3               3                            3      3
# 30               2               2                            2      2
# ...

# %%
marks = df['parental level of education']

# %%
marks.plot(color = ['red','green','blue','yellow','purple'],kind = "bar")

# %%
df1 = marks_data.groupby(by = 'reading score').count()
df1
# Out:
#                gender  race/ethnicity  parental level of education  lunch  \
# reading score
# 17                  1               1                            1      1
# 23                  1               1                            1      1
# 24                  2               2                            2      2
# 26                  1               1                            1      1
# 28                  1               1                            1      1
# 29                  2               2                            2      2
# 31                  2               2                            2      2
# 32                  1               1                            1      1
# 34                  4               4                            4      4
# 37                  3               3                            3      3
# 38                  2               2                            2      2
# ...

# %%
marks1 = df1['gender']

# %%
marks1.plot(kind = "bar")

# %%
df2 = marks_data.groupby(by = 'writing score').count()
df2
# Out:
#                gender  race/ethnicity  parental level of education  lunch  \
# writing score
# 10                  1               1                            1      1
# 15                  1               1                            1      1
# 19                  1               1                            1      1
# 22                  1               1                            1      1
# 23                  1               1                            1      1
# 27                  3               3                            3      3
# 28                  1               1                            1      1
# 30                  1               1                            1      1
# 32                  2               2                            2      2
# 33                  2               2                            2      2
# 34                  3               3                            3      3
# ...

# %%
marks2 = df2['math score']

# %%
marks2.plot(kind = "bar")

# %%
marks_data['math_passingScore'] = np.where(marks_data['math score']<35,'F','P')
marks_data.math_passingScore.value_counts()
# Out:
# P    978
# F     22
# Name: math_passingScore, dtype: int64

# %%
marks_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   math_passingScore reading_passingScore writing_passingScore
# 0                 P                    P                    P
# ...

# %%
df33 = marks_data.groupby(by='math_passingScore').count()
df33
# Out:
#                    gender  race/ethnicity  parental level of education  lunch  \
# math_passingScore
# F                      22              22                           22     22
# P                     978             978                          978    978
#
#                    test preparation course  math score  reading score  \
# math_passingScore
# F                                       22          22             22
# P                                      978         978            978
#
#                    writing score  reading_passingScore  writing_passingScore
# math_passingScore
# F                             22                    22                    22
# P                            978                   978                   978

# %%
df33['gender'].plot(kind = "pie")

# %%
marks_data['reading_passingScore'] = np.where(marks_data['reading score']<35,'F','P')
marks_data.reading_passingScore.value_counts()
# Out:
# P    985
# F     15
# Name: reading_passingScore, dtype: int64

# %%
df44 = marks_data.groupby(by = 'reading_passingScore').count()
df44
# Out:
#                       gender  race/ethnicity  parental level of education  \
# reading_passingScore
# F                         15              15                           15
# P                        985             985                          985
#
#                       lunch  test preparation course  math score  \
# reading_passingScore
# F                        15                       15          15
# P                       985                      985         985
#
#                       reading score  writing score  math_passingScore  \
# reading_passingScore
# F                                15             15                 15
# P                               985            985                985
#
#                       writing_passingScore
# reading_passingScore
# F                                       15
# P                                      985

# %%
df44['gender'].plot(kind = "bar")

# %%
marks_data['writing_passingScore'] = np.where(marks_data['writing score']<35,'F','P')
marks_data.writing_passingScore.value_counts()
# Out:
# P    983
# F     17
# Name: writing_passingScore, dtype: int64

# %%
df55 = marks_data.groupby(by = 'writing_passingScore').count()
df55
# Out:
#                       gender  race/ethnicity  parental level of education  \
# writing_passingScore
# F                         17              17                           17
# P                        983             983                          983
#
#                       lunch  test preparation course  math score  \
# writing_passingScore
# F                        17                       17          17
# P                       983                      983         983
#
#                       reading score  writing score  math_passingScore  \
# writing_passingScore
# F                                17             17                 17
# P                               983            983                983
#
#                       reading_passingScore
# writing_passingScore
# F                                       17
# P                                      983

# %%
df55['parental level of education'].plot(kind = "bar")
